# %%
import pandas as pandas

# %%
print("hello")

# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas ad pd
# Out:
#   Cell In[1], line 1
#     import pandas ad pd
#                   ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

print("Train shape:", train.shape)
print("Test shape:", test.shape)
# Out:
# Train shape: (1200, 13)
# Test shape: (120, 11)

# %%
train.head()
# Out:
#    id                                       journal_text ambience_type  \
# 0   1  The ocean ambience helped me stop drifting and...         ocean
# 1   2  I tried to relax during the forest ambience, y...        forest
# 2   3  The forest session slowed my thoughts and I fe...        forest
# 3   4  the mountain ambience was pleasant, though i c...      mountain
# 4   5  The rain session gave me a pause, but the pres...          rain
#
#    duration_min  sleep_hours  energy_level  stress_level time_of_day  \
# 0            12          6.5             4             2   afternoon
# 1            35          6.0             2             4     evening
# 2             3          NaN             2             1       night
# 3            25          7.0             4             4       night
# 4            25          5.0             3             5   afternoon
#
#   previous_day_mood face_emotion_hint reflection_quality emotional_state  \
# 0             mixed         calm_face              clear         focused
# 1              calm        tired_face              vague        restless
# 2       overwhelmed        happy_face              clear            calm
# 3           focused         calm_face              vague         neutral
# 4               NaN        tense_face              clear     overwhelmed
#
#    intensity
# 0          3
# 1          3
# 2          3
# 3          1
# 4          5

# %%
print(train.columns)
# Out:
# Index(['id', 'journal_text', 'ambience_type', 'duration_min', 'sleep_hours',
#        'energy_level', 'stress_level', 'time_of_day', 'previous_day_mood',
#        'face_emotion_hint', 'reflection_quality', 'emotional_state',
#        'intensity'],
#       dtype='str')

# %%
train.isnull().sum()
# Out:
# id                      0
# journal_text            0
# ambience_type           0
# duration_min            0
# sleep_hours             7
# energy_level            0
# stress_level            0
# time_of_day             0
# previous_day_mood      15
# face_emotion_hint     123
# reflection_quality      0
# emotional_state         0
# intensity               0
# dtype: int64

# %%
train['emotional_state'].value_counts()
# Out:
# emotional_state
# calm           216
# restless       209
# neutral        201
# focused        193
# mixed          191
# overwhelmed    190
# Name: count, dtype: int64

# %%
train['intensity'].value_counts()
# Out:
# intensity
# 4    277
# 3    240
# 5    229
# 2    228
# 1    226
# Name: count, dtype: int64

# %%
for i in range(5):
    print("TEXT:",train['journal_text'][i])
    print("STATE:",train['emotional_state'][i])
    print("INTENSITY:",train['intensity'][i])
    print("-"*50)
# Out:
# TEXT: The ocean ambience helped me stop drifting and concentrate on my next steps. My to-do list feels less chaotic.
# STATE: focused
# INTENSITY: 3
# --------------------------------------------------
# TEXT: I tried to relax during the forest ambience, yet my thoughts kept racing. I still feel a low buzz in my body.
# STATE: restless
# INTENSITY: 3
# --------------------------------------------------
# TEXT: The forest session slowed my thoughts and I feel more settled now.
# STATE: calm
# INTENSITY: 3
# --------------------------------------------------
# TEXT: the mountain ambience was pleasant, though i can't say it shifted my mood much. idk.
# STATE: neutral
# INTENSITY: 1
# --------------------------------------------------
# TEXT: The rain session gave me a pause, but the pressure is still sitting hard on me. I'm carrying too much in my head.
# STATE: overwhelmed
# INTENSITY: 5
# --------------------------------------------------
